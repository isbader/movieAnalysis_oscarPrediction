# %%
#pip install omdb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import imdb
import omdb

# %%
from omdb import OMDBClient

client = OMDBClient(apikey='33783cf6')

# %%
#omdb.get(title='True Grit', year=1969, fullplot=True, tomatoes=True, timeout=5)

# %%
moviesDB = imdb.IMDb()

# %%
Movies_ = pd.read_csv('/Users/bader/Dropbox/DSI_GA_Capstone/Code/Files/Movies_2000_fixedCast.csv')

# %%
Movies_
# Out:
#      year                                               name  Movie_ID  \
# 0    2000                                   Charlie's Angels   5033998
# 1    2000                                          Gladiator    172495
# 2    2000                     How the Grinch Stole Christmas   2709692
# 3    2000                                Requiem for a Dream    180093
# 4    2000                                Remember the Titans    210945
# ..    ...                                                ...       ...
# 413  2000                            Inshû meiki no iro onna   4135936
# 414  2000                                Ai, sono tabi-dachi   4138432
# 415  2000                                  Wars and Treasure   7201596
# 416  2000  National Japanese American Memorial: Groundbre...   8290150
# 417  2000                                           Yajamana   9315438
#
#      runtime                                               cast  \
# ...

# %%
display(dir(moviesDB))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_defModFunct',
#  '_getRefs',
#  '_get_infoset',
#  '_get_keyword',
#  '_get_real_characterID',
#  '_get_real_companyID',
#  '_get_real_movieID',
#  '_get_real_personID',
#  '_get_search_content',
#  '_get_search_movie_advanced_content',
#  '_get_top_bottom_movies',
#  '_http_logger',
#  '_keywordsResults',
#  '_mdparse',
#  '_normalize_characterID',
#  '_normalize_companyID',
#  '_normalize_movieID',
#  '_normalize_personID',
#  '_purge_seasons_data',
#  '_reraise_exceptions',
#  '_results',
#  '_retrieve',
#  '_searchIMDb',
#  '_search_character',
# ...

# %%
import ast
for i in Movies_['cast']:
    try:
        movie_cast = ast.literal_eval(i)
        
        print(movie_cast)
        print('\n')
        print('\n')
    except:
        print('Error')
# Out:
# ['Kristen Stewart', 'Naomi Scott', 'Ella Balinska', 'Elizabeth Banks', 'Patrick Stewart', 'Djimon Hounsou', 'Sam Claflin', 'Jonathan Tucker', 'Nat Faxon', 'Chris Pang', 'Luis Gerardo Méndez', 'Noah Centineo', 'David Schütter', 'Hannah Hoekstra', 'Jane Chirwa', 'Emre Kentmenoglu', 'Murali Perumal', 'Sebastian Kroehnert', 'Franz Xaver Zach', 'Andreas Schröders', 'Marie-Lou Sellem', 'Batur Belirdi', 'Anna Drexler', 'Tanem Çalbayram', 'Michael Strahan', 'Neil Malik Abdullah', 'Nick Dong-Sik', 'Dennenesch Zoudé', 'Peter Sikorski', 'Frederic Böhle', 'Eric Bouwer', 'Marco Grahl', 'Livia Matthes', 'Tessa Achtermann', 'Jabar Werner', 'Daria Nowak', 'Kiani Del Valle', 'Jakob Yaw Yeboah', 'Helen Aschauer', 'Robert Clotworthy', 'Jaclyn Smith', 'Danica Patrick', 'Ronda Rousey', 'Laverne Cox', 'Hailee Steinfeld', 'Chloe Kim', 'Lili Reinhart', 'Aly Raisman', 'Huda Kattan', 'Hélène Cardona', 'Mara Junot', 'Onur Can Karatas', 'Sarah Bennani', 'Frank Ferruccio', 'Jiana', 'Robert Maaser', 'Nathalie Nai
# ...

# %%
moviesDB.search_person('David Franzoni')[0].getID()
# Out:
# '0291905'

# %%
moviesDB.get_person('0829576').keys()
# Out:
# ['birth info',
#  'headshot',
#  'filmography',
#  'in development',
#  'name',
#  'imdbIndex',
#  'nick names',
#  'birth name',
#  'height',
#  'mini biography',
#  'trade mark',
#  'trivia',
#  'quotes',
#  'salary history',
#  'birth date',
#  'birth notes',
#  'canonical name',
#  'long imdb name',
#  'long imdb canonical name',
#  'full-size headshot']

# %%
birth info',
 'headshot',
 'filmography',
 'in development',
 'name',
 'imdbIndex',
 'nick names',
 'birth name',
 'height',
 'mini biography',
 'trade mark',
 'trivia',
 'quotes',
 'salary history',
 'birth date',
 'birth notes',
 'canonical name',
 'long imdb name',
 'long imdb canonical name',
 'full-size headshot'

# %%
moviesDB.get_person('0829576')['trade mark']
# Out:
# ['Often plays characters who are deeply troubled or have suffered an emotional trauma']

# %%
moviesDB.get_person('0829576')['birth date']
moviesDB.get_person('0829576')['in development']
# Out:
# [<Movie id:2251575[http] title:_Untitled William S. Burroughs Project (None)_>]

# %%
moviesDB.get_person_awards('0291905')
# Out:
# dict_keys(['data', 'titlesRefs', 'namesRefs'])

# %%
Movies_['production_company1']
# Out:
# 0            Columbia Pictures
# 1                   DreamWorks
# 2           Universal Pictures
# 3        Artisan Entertainment
# 4      Jerry Bruckheimer Films
#                 ...
# 413               Kunizawa Pro
# 414         Tantan-sha Company
# 415           Baran Film House
# 416               Bridge Media
# 417         Media House Studio
# Name: production_company1, Length: 418, dtype: object

# %%
moviesDB.get_movie_awards('5033998')
# Out:
# {'data': {}, 'titlesRefs': {}, 'namesRefs': {}}

# %%
res = omdb.request(t='True Grit', y=1969, r='xml')
xml_content = res.content
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-44-487ca7f5fc26> in <module>
# ----> 1 res = omdb.request(t='True Grit', y=1969, r='xml')
#       2 xml_content = res.content
#
# /opt/anaconda3/lib/python3.7/site-packages/omdb/api.py in request(**params)
#      56 def request(**params):
#      57     """Lower-level request."""
# ---> 58     return _client.request(**params)
#
# /opt/anaconda3/lib/python3.7/site-packages/omdb/client.py in request(self, **params)
#      53         # raise HTTP status code exception if status code != 200
#      54         # if status_code == 200, then no exception raised
# ---> 55         res.raise_for_status()
#      56
#      57         return res
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# ...
