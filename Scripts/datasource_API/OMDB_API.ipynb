# %%
import requests
import numpy as np
import pandas as pd

# %%
data = requests.get('http://www.omdbapi.com/?t=Gladiator+&y=2000&apikey=559f8f7f').json()
#data = requests.get(" http://www.omdbapi.com/?i=tt3896198&apikey=559f8f7f").json() 
data #Check the API Data
# Out:
# {'Title': 'Gladiator',
#  'Year': '2000',
#  'Rated': 'R',
#  'Released': '05 May 2000',
#  'Runtime': '155 min',
#  'Genre': 'Action, Adventure, Drama',
#  'Director': 'Ridley Scott',
#  'Writer': 'David Franzoni (story), David Franzoni (screenplay), John Logan (screenplay), William Nicholson (screenplay)',
#  'Actors': 'Russell Crowe, Joaquin Phoenix, Connie Nielsen, Oliver Reed',
#  'Plot': 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.',
#  'Language': 'English',
#  'Country': 'USA, UK, Malta, Morocco',
#  'Awards': 'Won 5 Oscars. Another 53 wins & 101 nominations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#   {'Source': 'Metacritic', 'Value': '67/100'}],
#  'Metascore': '67',
#  'imdbRating': '8.5',
#  'imdbVotes': '1,244,066',
#  'imdbID': 'tt0172495',
#  'Type': 'movie',
#  'DVD': '21 Nov 2000',
#  'BoxOffice': 'N/A',
#  'Production': 'Dreamworks Distribution LLC',
#  'Website': 'N/A',
#  'Response': 'True'}

# %%
data.keys()
# Out:
# dict_keys(['Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards', 'Poster', 'Ratings', 'Metascore', 'imdbRating', 'imdbVotes', 'imdbID', 'Type', 'DVD', 'BoxOffice', 'Production', 'Website', 'Response'])

# %%
# for i in data:
#     try:
#         i.append(data[i])
#     except KeyError:
#         i.append(None)

# %%
for i in data:
    print(data[i])
# Out:
# Gladiator
# 2000
# R
# 05 May 2000
# 155 min
# Action, Adventure, Drama
# Ridley Scott
# David Franzoni (story), David Franzoni (screenplay), John Logan (screenplay), William Nicholson (screenplay)
# Russell Crowe, Joaquin Phoenix, Connie Nielsen, Oliver Reed
# A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.
# English
# USA, UK, Malta, Morocco
# Won 5 Oscars. Another 53 wins & 101 nominations.
# https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg
# [{'Source': 'Internet Movie Database', 'Value': '8.5/10'}, {'Source': 'Rotten Tomatoes', 'Value': '76%'}, {'Source': 'Metacritic', 'Value': '67/100'}]
# 67
# 8.5
# 1,244,066
# tt0172495
# movie
# 21 Nov 2000
# N/A
# Dreamworks Distribution LLC
# N/A
# True

# %%
Movie_names = pd.read_csv('/Users/bader/Dropbox/DSI_GA_Capstone/Code/Names/names_2017_.csv')

# %%
Title_ = []
Year_ = []
Rated_ = []
Released_ = []
Runtime_ = []
Genre_ = []
Director_ = []
Writer_ = []
Actors_ = []
Plot_ = []
Language_ = []
Country_ = []
Awards_ = []
Ratings_ = []
Metascore_ = []
imdbRating_ = []
imdbVotes_ = []
imdbID_ = []
Type_ = []
DVD_ = []
BoxOffice_ = []
Production_ = []
Website_ = []
Response_ = []


count = 0
for name in Movie_names['name']:
    
    try:
    
        data = requests.get('http://www.omdbapi.com/?t={}+&y=2017&apikey=b892805a'.format(name)).json()

        try:
            Title_.append(data['Title'])
        except KeyError:
            Title_.append(None)

        try:
            Year_.append(data['Year'])
        except KeyError:
            Year_.append(None)

        try:
            Rated_.append(data['Rated'])
        except KeyError:
            Rated_.append(None)

        try:
            Released_.append(data['Released'])
        except KeyError:
            Released_.append(None)

        try:
            Runtime_.append(data['Runtime'])
        except KeyError:
            Runtime_.append(None)

        try:
            Genre_.append(data['Genre'])
        except KeyError:
            Genre_.append(None)

        try:
            Director_.append(data['Director'])
        except KeyError:
            Director_.append(None)

        try:
            Writer_.append(data['Writer'])
        except KeyError:
            Writer_.append(None)

        try:
            Actors_.append(data['Actors'])
        except KeyError:
            Actors_.append(None)

        try:
            Plot_.append(data['Plot'])
        except KeyError:
            Plot_.append(None)

        try:
            Language_.append(data['Language'])
        except KeyError:
            Language_.append(None)

        try:
            Country_.append(data['Country'])
        except KeyError:
            Country_.append(None)

        try:
            Awards_.append(data['Awards'])
        except KeyError:
            Awards_.append(None)

        try:
            Ratings_.append(data['Ratings'])
        except KeyError:
            Ratings_.append(None)

        try:
            Metascore_.append(data['Metascore'])
        except KeyError:
            Metascore_.append(None)

        try:
            imdbRating_.append(data['imdbRating'])
        except KeyError:
            imdbRating_.append(None)

        try:
            imdbVotes_.append(data['imdbVotes'])
        except KeyError:
            imdbVotes_.append(None)

        try:
            imdbID_.append(data['imdbID'])
        except KeyError:
            imdbID_.append(None)

        try:
            Type_.append(data['Type'])
        except KeyError:
            Type_.append(None)

        try:
            DVD_.append(data['DVD'])
        except KeyError:
            DVD_.append(None) 

        try:
            BoxOffice_.append(data['BoxOffice'])
        except KeyError:
            BoxOffice_.append(None) 

        try:
            Production_.append(data['Production'])
        except KeyError:
            Production_.append(None) 

        try:
            Website_.append(data['Website'])
        except KeyError:
            Website_.append(None) 

        try:
            Response_.append(data['Response'])
        except KeyError:
            Response_.append(None) 
            
    except:
        Title_.append(None)
        Year_.append(None)
        Rated_.append(None)
        Released_.append(None)
        Runtime_.append(None)
        Genre_.append(None)
        Director_.append(None)
        Writer_.append(None)
        Actors_.append(None)
        Plot_.append(None)
        Language_.append(None)
        Country_.append(None)
        Awards_.append(None)
        Ratings_.append(None)
        Metascore_.append(None)
        imdbRating_.append(None)
        imdbVotes_.append(None)
        imdbID_.append(None)
        Type_.append(None)
        DVD_.append(None)
        BoxOffice_.append(None)
        Production_.append(None)
        Website_.append(None)
        Response_.append(None)

    count= count +1
    print(count,end='')
# Out:
# ...

# %%
print(len(Title_))
print(len(Year_))
print(len(Rated_))
print(len(Released_))
print(len(Runtime_))
print(len(Genre_))
print(len(Writer_))
print(len(Actors_))
print(len(Plot_))
print(len(Language_))
print(len(Country_))
print(len(Awards_))
print(len(Ratings_))
print(len(Metascore_))
print(len(imdbRating_))
print(len(imdbVotes_))
print(len(imdbID_))
print(len(Type_))
print(len(DVD_))
print(len(BoxOffice_))
print(len(Production_))
print(len(Website_))
print(len(Response_))
# Out:
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956
# 956

# %%
type(Year_[0])
# Out:
# str

# %%
movie_data = {'Title':Title_,
              'Year':Year_,
              'Rated':Rated_,
              'Released':Released_,
              'Runtime':Runtime_,
              'Genre':Genre_,
              'Director':Director_,
              'Writer':Writer_,
              'Actors':Actors_,
              'Plot':Plot_,
              'Language':Language_,
              'Country':Country_,
              'Awards':Awards_,
              'Ratings':Ratings_,
              'Metascore':Metascore_,
              'imdbRating':imdbRating_,
              'imdbVotes':imdbVotes_,
              'imdbID':imdbID_,
              'Type':Type_,
              'DVD':DVD_,
              'BoxOffice':BoxOffice_,
              'Production':Production_,
              'Website':Website_,
              'Response':Response_}

movies = pd.DataFrame(movie_data)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 24 columns):
# Title         816 non-null object
# Year          816 non-null object
# Rated         816 non-null object
# Released      816 non-null object
# Runtime       816 non-null object
# Genre         816 non-null object
# Director      816 non-null object
# Writer        816 non-null object
# Actors        816 non-null object
# Plot          816 non-null object
# Language      816 non-null object
# Country       816 non-null object
# Awards        816 non-null object
# Ratings       816 non-null object
# Metascore     816 non-null object
# imdbRating    816 non-null object
# imdbVotes     816 non-null object
# imdbID        816 non-null object
# Type          816 non-null object
# DVD           815 non-null object
# BoxOffice     815 non-null object
# Production    815 non-null object
# Website       815 non-null object
# Response      951 non-null object
# dtypes: object(24)
# memory usage: 179.4+ KB

# %%
movies.head(100)
# Out:
#                                       Title  Year  Rated     Released  \
# 0            Jumanji: Welcome to the Jungle  2017  PG-13  20 Dec 2017
# 1   Star Wars: Episode VIII - The Last Jedi  2017  PG-13  15 Dec 2017
# 2                                        It  2017      R  08 Sep 2017
# 3                         Blade Runner 2049  2017      R  06 Oct 2017
# 4                      Call Me by Your Name  2017      R  19 Jan 2018
# ..                                      ...   ...    ...          ...
# 95                           The Dark Tower  2017  PG-13  04 Aug 2017
# 96                                   Cars 3  2017      G  16 Jun 2017
# 97                          Despicable Me 3  2017     PG  30 Jun 2017
# 98                               The Ritual  2017  TV-MA  09 Feb 2018
# 99                      The Death of Stalin  2017      R  09 Mar 2018
#
#     Runtime                                              Genre  \
# 0   119 min                 Action, Adventure, Comedy, Fantasy
# 1   152 min                 Action, Adventure, Fantasy, Sci-Fi
# 2   135 min                                             Horror
# 3   164 min           Action, Drama, Mystery, Sci-Fi, Thriller
# 4   132 min                                     Drama, Romance
# ..      ...                                                ...
# 95   95 min  Action, Adventure, Fantasy, Horror, Sci-Fi, We...
# 96  102 min        Animation, Adventure, Comedy, Family, Sport
# 97   89 min  Animation, Adventure, Comedy, Family, Fantasy,...
# 98   94 min                          Horror, Mystery, Thriller
# 99  107 min                             Comedy, Drama, History
#
#                                              Director  \
# 0                                         Jake Kasdan
# 1                                        Rian Johnson
# 2                                     Andy Muschietti
# 3                                    Denis Villeneuve
# 4                                     Luca Guadagnino
# ..                                                ...
# 95                                      Nikolaj Arcel
# 96                                          Brian Fee
# 97  Kyle Balda, Pierre Coffin, Eric Guillon(co-dir...
# 98                                     David Bruckner
# 99                                   Armando Iannucci
#
#                                                Writer  \
# 0   Chris McKenna (screenplay by), Erik Sommers (s...
# 1   Rian Johnson, George Lucas (based on character...
# 2   Chase Palmer (screenplay by), Cary Joji Fukuna...
# 3   Hampton Fancher (screenplay by), Michael Green...
# 4   James Ivory (screenplay by), André Aciman (bas...
# ..                                                ...
# 95  Akiva Goldsman (screenplay by), Jeff Pinkner (...
# 96  Brian Fee (original story by), Ben Queen (orig...
# 97                             Cinco Paul, Ken Daurio
# 98                    Joe Barton, Adam Nevill (novel)
# 99  Armando Iannucci, David Schneider, Ian Martin,...
#
#                                                Actors  \
# 0   Dwayne Johnson, Kevin Hart, Jack Black, Karen ...
# 1   Mark Hamill, Carrie Fisher, Adam Driver, Daisy...
# 2   Jaeden Martell, Jeremy Ray Taylor, Sophia Lill...
# 3   Ryan Gosling, Dave Bautista, Robin Wright, Mar...
# 4   Armie Hammer, Timothée Chalamet, Michael Stuhl...
# ..                                                ...
# 95  Matthew McConaughey, Idris Elba, Tom Taylor, D...
# 96  Owen Wilson, Cristela Alonzo, Chris Cooper, Na...
# 97  Steve Carell, Kristen Wiig, Trey Parker, Miran...
# 98  Rafe Spall, Arsher Ali, Robert James-Collier, ...
# 99  Olga Kurylenko, Tom Brooke, Paddy Considine, J...
#
#                                                  Plot  ... Metascore  \
# 0   Four teenagers are sucked into a magical video...  ...        58
# 1   Rey develops her newly discovered abilities wi...  ...        85
# 2   In the summer of 1989, a group of bullied kids...  ...        69
# 3   A young blade runner's discovery of a long-bur...  ...        81
# 4   In 1980s Italy, a romance blossoms between a s...  ...        93
# ..                                                ...  ...       ...
# 95  A boy haunted by visions of a dark tower from ...  ...        34
# 96  Lightning McQueen sets out to prove to a new g...  ...        59
# 97  Gru meets his long-lost charming, cheerful, an...  ...        49
# 98  A group of college friends reunite for a trip ...  ...        57
# 99  Moscow, 1953. After being in power for nearly ...  ...        88
#
#    imdbRating imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 0         6.9   256,574  tt2283362  movie  20 Mar 2018  $393,201,353
# 1         7.1   481,503  tt2527336  movie  27 Mar 2018  $619,117,636
# 2         7.3   404,288  tt1396484  movie  09 Jan 2018  $326,898,358
# 3         8.0   398,240  tt1856101  movie  16 Jan 2018   $91,800,042
# 4         7.9   165,719  tt5726616  movie  13 Mar 2018           N/A
# ..        ...       ...        ...    ...          ...           ...
# 95        5.6   115,141  tt1648190  movie  31 Oct 2017   $50,644,837
# 96        6.7    63,508  tt3606752  movie  07 Nov 2017  $152,603,003
# 97        6.3    98,465  tt3469046  movie  05 Dec 2017  $264,194,540
# 98        6.3    61,948  tt5638642  movie  09 Feb 2018           N/A
# 99        7.2    68,253  tt4686844  movie  19 Jun 2018           N/A
#
#                 Production Website Response
# 0        Columbia Pictures     N/A     True
# 1     Walt Disney Pictures     N/A     True
# 2    Warner Bros. Pictures     N/A     True
# 3    Warner Bros. Pictures     N/A     True
# 4   Sony Pictures Classics     N/A     True
# ..                     ...     ...      ...
# 95           Sony Pictures     N/A     True
# 96    Walt Disney Pictures     N/A     True
# 97      Universal Pictures     N/A     True
# 98                 Netflix     N/A     True
# 99               IFC Films     N/A     True
#
# [100 rows x 24 columns]

# %%
movies.to_csv('movies_2017_new.csv',index = False,header=True)

# %%
# for i in data:
    
#     try:
#         list('{}_'.format(i)).append(data[i])
#     except KeyError:
#         list('{}_'.format(i)).append(None)
