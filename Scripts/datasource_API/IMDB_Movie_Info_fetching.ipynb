# %%
#pip install imdbpy

# %%
import numpy as np
import pandas as pd
import imdb

# %%
moviesDB = imdb.IMDb() #Access the DataBase

# %%
#List_of_movie_names = ['names_2000_2001.csv','names_2002_2003.csv','names_2004_2005','names_2006_2007.csv','names_2008_2009.csv','names_2010_2011.csv','names_2012_2013.csv','names_2014_2015.csv','names_2016_2017.csv']

# %%
Movie_names = pd.read_csv('./Names/names_2017_.csv') #Get the movie names
Movies_ = Movie_names
Movies_.drop_duplicates(keep='first',inplace=True)

# %%
Movies_.head(10)
# Out:
#    year                                     name
# 0  2017           Jumanji: Welcome to the Jungle
# 1  2017  Star Wars: Episode VIII - The Last Jedi
# 2  2017                                       It
# 3  2017                        Blade Runner 2049
# 4  2017                     Call Me by Your Name
# 5  2017                                 Baywatch
# 6  2017                           Justice League
# 7  2017              Kingsman: The Golden Circle
# 8  2017                     The Greatest Showman
# 9  2017                           Thor: Ragnarok

# %%
display(dir(moviesDB)) #Understand the functions in the library
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_defModFunct',
#  '_getRefs',
#  '_get_infoset',
#  '_get_keyword',
#  '_get_real_characterID',
#  '_get_real_companyID',
#  '_get_real_movieID',
#  '_get_real_personID',
#  '_get_search_content',
#  '_get_search_movie_advanced_content',
#  '_get_top_bottom_movies',
#  '_http_logger',
#  '_keywordsResults',
#  '_mdparse',
#  '_normalize_characterID',
#  '_normalize_companyID',
#  '_normalize_movieID',
#  '_normalize_personID',
#  '_purge_seasons_data',
#  '_reraise_exceptions',
#  '_results',
#  '_retrieve',
#  '_searchIMDb',
#  '_search_character',
#  '_search_company',
#  '_search_episode',
#  '_search_keyword',
#  '_search_movie',
#  '_search_movie_advanced',
#  '_search_person',
#  'accessSystem',
#  'character2imdbID',
#  'compProxy',
#  'company2imdbID',
#  'del_cookies',
#  'do_adult_search',
#  'get_bottom100_movies',
#  'get_character',
#  'get_character_infoset',
#  'get_company',
#  'get_company_infoset',
#  'get_company_main',
#  'get_episode',
#  'get_imdbCharacterID',
#  'get_imdbCompanyID',
#  'get_imdbID',
#  'get_imdbMovieID',
#  'get_imdbPersonID',
#  'get_imdbURL',
#  'get_keyword',
#  'get_movie',
#  'get_movie_airing',
#  'get_movie_akas',
#  'get_movie_alternate_versions',
#  'get_movie_awards',
#  'get_movie_connections',
#  'get_movie_crazy_credits',
#  'get_movie_critic_reviews',
#  'get_movie_episodes',
#  'get_movie_external_reviews',
#  'get_movie_external_sites',
#  'get_movie_faqs',
#  'get_movie_full_credits',
#  'get_movie_goofs',
#  'get_movie_infoset',
#  'get_movie_keywords',
#  'get_movie_locations',
#  'get_movie_main',
#  'get_movie_misc_sites',
#  'get_movie_news',
#  'get_movie_official_sites',
#  'get_movie_parents_guide',
#  'get_movie_photo_sites',
#  'get_movie_plot',
#  'get_movie_quotes',
#  'get_movie_release_dates',
#  'get_movie_release_info',
#  'get_movie_reviews',
#  'get_movie_sound_clips',
#  'get_movie_soundtrack',
#  'get_movie_synopsis',
#  'get_movie_taglines',
#  'get_movie_technical',
#  'get_movie_trivia',
#  'get_movie_tv_schedule',
#  'get_movie_video_clips',
#  'get_movie_vote_details',
#  'get_person',
#  'get_person_awards',
#  'get_person_biography',
#  'get_person_filmography',
#  'get_person_genres_links',
#  'get_person_infoset',
#  'get_person_keywords_links',
#  'get_person_main',
#  'get_person_news',
#  'get_person_official_sites',
#  'get_person_other_works',
#  'get_person_publicity',
#  'get_proxy',
#  'get_special_methods',
#  'get_top250_movies',
#  'mProxy',
#  'name2imdbID',
#  'new_character',
#  'new_company',
#  'new_movie',
#  'new_person',
#  'pProxy',
#  'scompProxy',
#  'search_character',
#  'search_company',
#  'search_episode',
#  'search_keyword',
#  'search_movie',
#  'search_movie_advanced',
#  'search_person',
#  'set_cookies',
#  'set_imdb_urls',
#  'set_proxy',
#  'set_timeout',
#  'skProxy',
#  'smProxy',
#  'smaProxy',
#  'spProxy',
#  'title2imdbID',
#  'topBottomProxy',
#  'update',
#  'urlOpener',
#  'urls']

# %%
Movie_id = []
for i in Movies_['name']:
    Movie_id.append(moviesDB.search_movie(i)[0].getID())

# %%
Movies_['Movie_ID'] = Movie_id

# %%
Movies_.head()
# Out:
#    year                                     name Movie_ID
# 0  2017           Jumanji: Welcome to the Jungle  2283362
# 1  2017  Star Wars: Episode VIII - The Last Jedi  2527336
# 2  2017                                       It  1396484
# 3  2017                        Blade Runner 2049  1856101
# 4  2017                     Call Me by Your Name  5726616

# %%
runtime = []
cast = []
genres = []
runtimes = []
country_codes = []
language_codes = []
certificates = []
box_office = []
rating = []
votes = []
original_air_date = []
title = []
directors = []
writers = []
producers = []
composers = []
editors = []
cinematographers = []
set_decorators = []
production_companies = []
assistant_directors = []
visual_effects = []

count = 0
for i in Movies_['Movie_ID']:
    
    movie = moviesDB.get_movie(i)
    
    try:
        cast.append(movie['cast'])
    except KeyError:
        cast.append(None)
        
    try:
        runtime.append(movie['runtime'][0])
    except KeyError:
        runtime.append(None)
    
    try:
        genres.append(movie['genres'])
    except KeyError:
        genres.append(None)
        
    try:
        country_codes.append(movie['country codes'])
    except KeyError:
        country_codes.append(None)
        
    try:
        language_codes.append(movie['language codes'])
    except KeyError:
        language_codes.append(None)
    
    try:
        USRate = [s for s in movie['certificates'] if "United States" in s]
        if len(USRate) > 0:
            certificates.append(USRate[0].replace('United States:',''))
        else:
            certificates.append(None)

    except KeyError:
        certificates.append(None)
        
    try:
        box_office.append(movie['box office'])
    except KeyError:
        box_office.append(None)
        
    try:
        rating.append(movie['rating'])
    except KeyError:
        rating.append(None)
        
    try:
        votes.append(movie['votes'])
    except KeyError:
        votes.append(None)
    
    try:
        original_air_date.append(movie['original air date'])
    except KeyError:
        original_air_date.append(None)
        
    try:
        title.append(movie['title'])
    except KeyError:
        title.append(None)
        
    try:
        directors.append(movie['directors'])
    except KeyError:
        directors.append(None)
        
    try:
        writers.append(movie['writers'])
    except KeyError:
        writers.append(None)
        
    try:
        producers.append(movie['producers'])
    except KeyError:
        producers.append(None)
        
    try:
        composers.append(movie['composers'])
    except KeyError:
        composers.append(None)
        
    try:
        editors.append(movie['editors'])
    except KeyError:
        editors.append(None)
        
    try:
        cinematographers.append(movie['cinematographers'])
    except KeyError:
        cinematographers.append(None)
        
    try:
        set_decorators.append(movie['set decorators'])
    except KeyError:
        set_decorators.append(None)
        
    try:
        production_companies.append(movie['production companies'])
    except KeyError:
        production_companies.append(None)
        
    try:
        assistant_directors.append(movie['assistant directors'])
    except KeyError:
        assistant_directors.append(None)
        
    try:
        visual_effects.append(movie['visual effects'])
    except KeyError:
        visual_effects.append(None) 
    count= count +1
    print(count,i)
# Out:
# 1 2283362
# 2 2527336
# 3 1396484
# 4 1856101
# 5 5726616
# 6 1469304
# 7 0974015
# 8 4649466
# 9 1485796
# 10 3501632
# 11 5052448
# 12 5742374
# 13 3896198
# 14 5013056
# 15 2771200
# 16 2543472
# 17 2250912
# 18 3402236
# 19 1790809
# 20 3315342
# 21 2380307
# 22 5027774
# 23 3890160
# 24 2140507
# 25 4209788
# 26 3717490
# 27 0451279
# 28 5580390
# 29 4925292
# 30 5109784
# 31 1389072
# 32 3371366
# 33 3748172
# 34 2239822
# 35 4425200
# 36 4630562
# 37 4555426
# 38 4846232
# 39 4225622
# 40 1219827
# 41 2316204
# 42 3967856
# 43 3731562
# 44 5580036
# 45 5715874
# 46 3521126
# 47 6433880
# 48 5519340
# 49 4465564
# 50 1758810
# 51 5776858
# 52 4815122
# 53 1981128
# 54 2345759
# 55 6359956
# 56 5362988
# 57 1972591
# 58 2406566
# 59 3532216
# 60 5478478
# 61 3450958
# 62 1987680
# 63 5439796
# 64 5442430
# 65 7608418
# 66 6294822
# 67 2932536
# 68 5657846
# 69 5308322
# 70 1648190
# 71 3606752
# 72 3469046
# 73 5638642
# 74 4686844
# 75 5635086
# 76 1959563
# 77 5093026
# 78 4765284
# 79 4695012
# 80 3829920
# 81 6214928
# 82 1536537
# 83 7608534
# 84 5294550
# 85 1961175
# 86 4396630
# 87 0491175
# 88 4633690
# 89 4795124
# 90 5649144
# 91 4758646
# 92 2378507
# 93 1615160
# 94 6408226
# 95 5536736
# 96 6108178
# 97 5666304
# 98 4587656
# 99 4287320
# 100 1753383
# 101 0387564
# 102 5462602
# 103 2763304
# 104 4995790
# 105 1293847
# 106 0493405
# 107 5719700
# 108 4565520
# 109 4799050
# 110 1412528
# 111 5592248
# 112 6000478
# 113 5390504
# 114 5140878
# 115 2039338
# 116 5657856
# 117 6225520
# 118 0877057
# 119 1666185
# 120 3411444
# 121 5649108
# 122 6053438
# 123 3986820
# 124 6265828
# 125 1837642
# 126 2396589
# 127 3416536
# 128 5884234
# 129 3922818
# 130 6133130
# 131 5541240
# 132 5479616
# 133 3564472
# 134 4468740
# 135 4877122
# 136 5962210
# 137 2291540
# 138 1734493
# 139 1691916
# 140 1966359
# 141 3860916
# 142 2226597
# 143 3874544
# 144 4116284
# 145 5322012
# 146 2582784
# 147 3758172
# 148 3300980
# 149 0491203
# 150 5516328
# 151 3563262
# 152 4080956
# 153 5716464
# 154 2568862
# 155 5727282
# 156 4622512
# 157 2062700
# 158 3750872
# 159 4547194
# 160 3881784
# 161 3011960
# 162 1935194
# 163 5816682
# 164 3262342
# 165 4682788
# 166 6304046
# 167 5723272
# 168 6800942
# 169 5825380
# 170 5462326
# 171 1544608
# 172 2872518
# 173 4581576
# 174 2582576
# 175 5978724
# 176 1869347
# 177 5862312
# 178 4882376
# 575 10515546
# 576 1286130
# 577 0101707
# 578 10505044
# 579 9608078
# 580 6984772
# 581 5876326
# 582 8993120
# 583 0071828
# 584 1407978
# 585 5456862
# 586 5080732
# 587 7023340
# 588 8702270
# 589 9643256
# 590 6728214
# 591 6646726
# 592 9784636
# 593 6416766
# 594 7528064
# 595 10701758
# 596 7245120
# 597 4632066
# 598 6234736
# 599 6488074
# 600 10326660
# 601 0810784
# 602 5835496
# 603 7171690
# 604 6543714
# 605 6690182
# 606 8959708
# 607 6524116
# 608 5673486
# 609 0367082
# 610 7004788
# 611 7530302
# 612 7527702
# 613 10741880
# 614 5645602
# 615 3906366
# 616 8076964
# 617 2901560
# 618 2751064
# 619 2380301
# 620 6331484
# 621 7088506
# 622 0067630
# 623 7658354
# 624 6504302
# 625 3646472
# 626 6642482
# 627 6097528
# 628 7886886
# 629 6686136
# 630 0490215
# 631 6516652
# 632 6733176
# 633 4048342
# 634 3809960
# 635 3333158
# 636 6834874
# 637 6961914
# 638 6677630
# 639 5745444
# 640 10805072
# 641 0114234
# 642 11020292
# 643 0112732
# 644 7162208
# 645 6382722
# 646 5180056
# 647 7256582
# 648 7598728
# 649 9463304
# 650 5767604
# 651 10794616
# 652 4549072
# 653 2168882
# 654 7444462
# 655 7283046
# 656 8636926
# 657 6289828
# 658 10285260
# 659 6728386

# %%
#cast_

# %%
# cast 

cast1_ = []
for d in cast:
    single = []
    try:
        for i in d:
            single.append(str(i))
        cast1_.append(single)
    except:
        cast1_.append(None)




# directors 

director=[]

for d in directors:
    try:
        director.append(str(d[0]))

    except:
            director.append(None)


#producers

producer1=[]
producer2=[]

for d in producers:
    try:
        producer1.append(str(d[0]))
        if len(d)>1:
            producer2.append(str(d[1]))
        else:
            producer2.append(None)
    except:
            producer1.append(None)
            producer2.append(None)

#writers

writer1=[]
writer2=[]
print ('writers',len(writers))
for d in writers:
    try:
        writer1.append(str(d[0]))
        if len(d)>1:
            writer2.append(str(d[1]))
        else:
            writer2.append(None)
    except:
            writer1.append(None)
            writer2.append(None)

        
        
#production_companies

production_company1 = []
production_company2 = []
print ('production_companies',len(production_companies))


for d in production_companies:
    try:
        production_company1.append(str(d[0]))
        if len(d)>1:
            production_company2.append(str(d[1]))
        else:
            production_company2.append(None)    
    except:
            production_company1.append(None)
            production_company2.append(None)    

print ('production_company1',len(production_company1))
# Out:
# writers 659
# production_companies 659
# production_company1 659

# %%
#editors 

editor=[]


for d in editors:
    try:
        editor.append(str(d[0]))
    except:
        editor.append(None) 

#composers 

composer=[]

for d in composers:
    try:
        composer.append(str(d[0]))
    except:
        composer.append(None) 
    
#cinematographers

cinematographer = []

for d in cinematographers:
    try:
        cinematographer.append(str(d[0]))
    except:
        cinematographer.append(None) 
    
#set_decorators

set_decorator=[]

for d in set_decorators:
    try:
        set_decorator.append(str(d[0]))
    except:
        set_decorator.append(None) 
    

#assistant_directors

assistant_director=[]

for d in assistant_directors:
   
    try:
        assistant_director.append(str(d[0]))
    except:
        assistant_director.append(None) 
    

#visual_effects

visual_effect=[]

for d in visual_effects:
    try:
        visual_effect.append(str(d[0]))
    except:
        visual_effect.append(None)

# %%
#Budget, Opening Weekend United States, Cumulative Worldwide Gross

Budget=[]
OWUS =[]
CWG = []

for d in box_office:
    try:
        Budget.append(int(d['Budget'].replace(' (estimated)','').replace('$','').replace(',','') ))
    except:
        Budget.append(None) 
    try:
        OWUS.append(d['Opening Weekend United States'])
    except:
        OWUS.append(None) 
    try:
        CWG.append(int(d['Cumulative Worldwide Gross'].replace('$','').replace(',','')))
    except:
        CWG.append(None) 
        
        
        
#genres
genre=[]

for d in genres:
   
    try:
        genre.append(str(d))
    except:
        genre.append(None) 
    

#genre1 = []
#genre2 = []
#genre3 = []

#for d in genres:
#    try:
#        genre1.append(d[0])
#    except:
#        genre1.append(None)
#    try:
#        genre2.append(d[1])
#    except:
#        genre2.append(None) 
#    try:
#        genre3.append(d[2])
#    except:
#        genre3.append(None)

# %%
#directors = list(map(str, directors))
#director2 = list(map(str, directors[0]))
#producers = list(map(str, producers))
#writers = list(map(str, writers))
#composers = list(map(str, composers))
#editors = list(map(str, editors))
#cinematographers = list(map(str, cinematographers))
#set_decorators = list(map(str, set_decorators))
#production_companies = list(map(str, production_companies))
#assistant_directors = list(map(str, assistant_directors))
#visual_effects = list(map(str, visual_effects))

# %%
#My_movies.insert(len(My_movies.columns),'runtime', runtime,True)

# %%
runtime
# Out:
# ['119',
#  '152',
#  '135',
#  '164',
#  '132',
#  '116',
#  '120',
#  '141',
#  '105',
#  '130',
#  '104',
#  '89',
#  '136',
#  '106',
#  '129',
#  '113',
#  '133',
#  '114',
#  '129',
#  '137',
#  '105',
#  '115',
#  '113',
#  '102',
#  '140',
#  '124',
#  '141',
#  '123',
#  '94',
#  '121',
#  '135',
#  '154',
#  '103',
#  '137',
#  '122',
#  '136',
#  '125',
#  '101',
#  '85',
#  '107',
#  '122',
#  '120',
#  '118',
#  '120',
#  '121',
#  '104',
#  '93',
#  '117',
#  '118',
#  '119',
#  '130',
#  '87',
#  '109',
#  '110',
#  '104',
#  '107',
#  '126',
#  '115',
#  '115',
#  '134',
#  '140',
#  '126',
#  '118',
#  '104',
#  '92',
#  '116',
#  '89',
#  '100',
#  '96',
#  '95',
#  '102',
#  '89',
#  '94',
#  '107',
#  '104',
#  '118',
#  '133',
#  '93',
#  '91',
#  '134',
#  '102',
#  '123',
#  '104',
#  '132',
#  '112',
#  '43',
#  '105',
#  '121',
#  '115',
#  '111',
#  '122',
#  '127',
#  '113',
#  '117',
#  '112',
#  '114',
#  '90',
#  '86',
#  '110',
#  '100',
#  '103',
#  '120',
#  '117',
#  '151',
#  '107',
#  '100',
#  '97',
#  '88',
#  '101',
#  '87',
#  '93',
#  '122',
#  '143',
#  '109',
#  '109',
#  '132',
#  '104',
#  '24',
#  '139',
#  '108',
#  '92',
#  '113',
#  '111',
#  '92',
#  '44',
#  '134',
#  '107',
#  '97',
#  '120',
#  '108',
#  '107',
#  '105',
#  '122',
#  '103',
#  '86',
#  '98',
#  '107',
#  '98',
#  '98',
#  '113',
#  '105',
#  '112',
#  '97',
#  '104',
#  '90',
#  '90',
#  '115',
#  '135',
#  '105',
#  '98',
#  '112',
#  '116',
#  '118',
#  '96',
#  '93',
#  None,
#  '141',
#  '90',
#  '166',
#  None,
#  '91',
#  '97',
#  '115',
#  '79',
#  None,
#  '106',
#  '82',
#  '101',
#  '118',
#  '80',
#  '88',
#  '87',
#  '80',
#  '118',
#  None,
#  '130',
#  '114',
#  '94',
#  '100',
#  '86',
#  '82',
#  '60',
#  '82',
#  '87',
#  '112',
#  '81',
#  '91',
#  '90',
#  '83',
#  None,
#  '99',
#  '60',
#  '45',
#  '87',
#  '85',
#  '60',
#  '98',
#  '79',
#  '92',
#  '85',
#  None,
#  '105',
#  '121',
#  None,
#  None,
#  '95',
#  '75',
#  '85',
#  '80',
#  '143',
#  None,
#  '138',
#  '91',
#  '90',
#  '125',
#  '95',
#  '125',
#  '126',
#  None,
#  '107',
#  '90',
#  None,
#  '98',
#  '103',
#  '85',
#  '60',
#  '92',
#  None,
#  '70',
#  '105',
#  '110',
#  '135',
#  '85',
#  '118',
#  '120',
#  '85',
#  '96',
#  '95',
#  '90',
#  '60',
#  None,
#  None,
#  '65',
#  '106',
#  '70',
#  None,
#  '88',
#  '77',
#  None,
#  '59',
#  '75',
#  None,
#  '109',
#  '93',
#  '116',
#  '126',
#  '93',
#  '91',
#  None,
#  '115',
#  '93',
#  None,
#  '83',
#  '78',
#  '95',
#  '75',
#  '91',
#  '83',
#  '93',
#  '14',
#  '103',
#  '88',
#  None,
#  '92',
#  '108',
#  '90',
#  '128',
#  '13',
#  None,
#  '70',
#  '112',
#  None,
#  '119',
#  '77',
#  '99',
#  '80',
#  '90',
#  None,
#  None,
#  '80',
#  '102',
#  '94',
#  '80',
#  '120',
#  '90',
#  '102',
#  '240',
#  None,
#  '116',
#  None,
#  '62',
#  None,
#  '64',
#  '92',
#  '86',
#  None,
#  '107',
#  '22',
#  None,
#  None,
#  '112',
#  '103',
#  None,
#  None,
#  '100',
#  None,
#  None,
#  '74',
#  '140',
#  None,
#  '81',
#  '71',
#  '90',
#  '62',
#  '100',
#  None,
#  None,
#  None,
#  '158',
#  None,
#  '90',
#  '100',
#  '80',
#  None,
#  '10',
#  '119',
#  '90',
#  None,
#  '76',
#  '89',
#  None,
#  None,
#  None,
#  '140',
#  '45',
#  '91',
#  '85',
#  None,
#  '71',
#  '90',
#  None,
#  '78',
#  '60',
#  '67',
#  None,
#  None,
#  '85',
#  '127',
#  '76',
#  None,
#  '96',
#  '82',
#  None,
#  None,
#  '161',
#  None,
#  '76',
#  '80',
#  '90',
#  None,
#  None,
#  '120',
#  '75',
#  None,
#  '90',
#  '142',
#  None,
#  '96',
#  None,
#  '75',
#  '82',
#  '80',
#  '160',
#  None,
#  None,
#  '90',
#  '81',
#  '80',
#  '75',
#  None,
#  '95',
#  None,
#  '48',
#  None]

# %%
Movies_['runtime'] = runtime

Movies_['cast'] = cast1_

Movies_['genre'] = genre
#Movies_2016_2017['genre2'] = genre2
#Movies_2016_2017['genre3'] = genre3

Movies_['country_codes'] = country_codes
Movies_['language_codes'] = language_codes
Movies_['certificates'] = certificates

Movies_['Budget'] = Budget
Movies_['OWUS'] = OWUS
Movies_['CWG'] = CWG

Movies_['rating'] = rating
Movies_['votes'] = votes
Movies_['original_air_date'] = original_air_date
Movies_['title'] = title

Movies_['director'] = director

Movies_['writer1'] = writer1
Movies_['writer2'] = writer2

Movies_['producer1'] = producer1
Movies_['producer2'] = producer2

Movies_['production_company1'] = production_company1
Movies_['production_company2'] = production_company2

Movies_['composers'] = composer
Movies_['editors'] = editor
Movies_['cinematographers'] = cinematographer
Movies_['set_decorators'] = set_decorator
Movies_['assistant_directors'] = assistant_director
Movies_['visual_effects'] = visual_effect

# %%
Movies_.head()
# Out:
#    year                                     name Movie_ID runtime  \
# 0  2017           Jumanji: Welcome to the Jungle  2283362     119
# 1  2017  Star Wars: Episode VIII - The Last Jedi  2527336     152
# 2  2017                                       It  1396484     135
# 3  2017                        Blade Runner 2049  1856101     164
# 4  2017                     Call Me by Your Name  5726616     132
#
#                                                 cast  \
# 0  [Dwayne Johnson, Kevin Hart, Jack Black, Karen...
# 1  [Mark Hamill, Carrie Fisher, Adam Driver, Dais...
# 2  [Jaeden Martell, Jeremy Ray Taylor, Sophia Lil...
# 3  [Ryan Gosling, Dave Bautista, Robin Wright, Ma...
# 4  [Armie Hammer, Timothée Chalamet, Michael Stuh...
#
#                                                genre  \
# 0       ['Action', 'Adventure', 'Comedy', 'Fantasy']
# 1       ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 2                                         ['Horror']
# 3  ['Action', 'Drama', 'Mystery', 'Sci-Fi', 'Thri...
# 4                               ['Drama', 'Romance']
#
#               country_codes                language_codes certificates  \
# 0  [us, in, ca, gb, au, de]                          [en]        PG-13
# 1                      [us]                          [en]        PG-13
# 2                  [us, ca]                          [en]            R
# 3      [us, gb, hu, ca, es]  [en, fi, ja, hu, ru, so, es]            R
# 4                  [it, fr]          [en, it, fr, de, he]            R
#
#         Budget  ...       producer1           producer2   production_company1  \
# 0   90000000.0  ...       Ted Field         Dany Garcia     Columbia Pictures
# 1  317000000.0  ...     J.J. Abrams      Pippa Anderson  Walt Disney Pictures
# 2   35000000.0  ...  Richard Brener        Doug Davison       New Line Cinema
# 3  150000000.0  ...      Yale Badik      Dana Belcastro   Alcon Entertainment
# 4          NaN  ...      Naima Abed  Margarethe Baillou  Frenesy Film Company
#
#          production_company2           composers           editors  \
# 0   Matt Tolmach Productions       Henry Jackman     Steve Edwards
# 1                  Lucasfilm       John Williams        Bob Ducsay
# 2  RatPac-Dune Entertainment  Benjamin Wallfisch  Jason Ballantine
# 3          Columbia Pictures  Benjamin Wallfisch        Joe Walker
# 4             La Cinéfacture                None     Walter Fasano
#
#       cinematographers       set_decorators         assistant_directors  \
# 0          Gyula Pados      Ronald R. Reiss       Rahul Singh Agnihotri
# 1         Steve Yedlin      Richard Roberts                 Luksa Benic
# 2     Chung-hoon Chung        Rosalie Board                 Simon Board
# 3        Roger Deakins  Alessandra Querzola               Gergely Apjok
# 4  Sayombhu Mukdeeprom        Muriel Chinal  Ferdinando Cito Filomarino
#
#        visual_effects
# 0        Resham Aaron
# 1       Darrell Abney
# 2       Rubén Algarra
# 3       Keith Acheson
# 4  Emanuel Bartolozzi
#
# [5 rows x 29 columns]

# %%
export_csv = Movies_.to_csv (r'Movies_2017_fixedCast.csv', index = None, header=True)

# %%
Movies_.head()
# Out:
#    year                                     name Movie_ID runtime  \
# 0  2017           Jumanji: Welcome to the Jungle  2283362     119
# 1  2017  Star Wars: Episode VIII - The Last Jedi  2527336     152
# 2  2017                                       It  1396484     135
# 3  2017                        Blade Runner 2049  1856101     164
# 4  2017                     Call Me by Your Name  5726616     132
#
#                                                 cast  \
# 0  [Dwayne Johnson, Kevin Hart, Jack Black, Karen...
# 1  [Mark Hamill, Carrie Fisher, Adam Driver, Dais...
# 2  [Jaeden Martell, Jeremy Ray Taylor, Sophia Lil...
# 3  [Ryan Gosling, Dave Bautista, Robin Wright, Ma...
# 4  [Armie Hammer, Timothée Chalamet, Michael Stuh...
#
#                                                genre  \
# 0       ['Action', 'Adventure', 'Comedy', 'Fantasy']
# 1       ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 2                                         ['Horror']
# 3  ['Action', 'Drama', 'Mystery', 'Sci-Fi', 'Thri...
# 4                               ['Drama', 'Romance']
#
#               country_codes                language_codes certificates  \
# 0  [us, in, ca, gb, au, de]                          [en]        PG-13
# 1                      [us]                          [en]        PG-13
# 2                  [us, ca]                          [en]            R
# 3      [us, gb, hu, ca, es]  [en, fi, ja, hu, ru, so, es]            R
# 4                  [it, fr]          [en, it, fr, de, he]            R
#
#         Budget  ...       producer1           producer2   production_company1  \
# 0   90000000.0  ...       Ted Field         Dany Garcia     Columbia Pictures
# 1  317000000.0  ...     J.J. Abrams      Pippa Anderson  Walt Disney Pictures
# 2   35000000.0  ...  Richard Brener        Doug Davison       New Line Cinema
# 3  150000000.0  ...      Yale Badik      Dana Belcastro   Alcon Entertainment
# 4          NaN  ...      Naima Abed  Margarethe Baillou  Frenesy Film Company
#
#          production_company2           composers           editors  \
# 0   Matt Tolmach Productions       Henry Jackman     Steve Edwards
# 1                  Lucasfilm       John Williams        Bob Ducsay
# 2  RatPac-Dune Entertainment  Benjamin Wallfisch  Jason Ballantine
# 3          Columbia Pictures  Benjamin Wallfisch        Joe Walker
# 4             La Cinéfacture                None     Walter Fasano
#
#       cinematographers       set_decorators         assistant_directors  \
# 0          Gyula Pados      Ronald R. Reiss       Rahul Singh Agnihotri
# 1         Steve Yedlin      Richard Roberts                 Luksa Benic
# 2     Chung-hoon Chung        Rosalie Board                 Simon Board
# 3        Roger Deakins  Alessandra Querzola               Gergely Apjok
# 4  Sayombhu Mukdeeprom        Muriel Chinal  Ferdinando Cito Filomarino
#
#        visual_effects
# 0        Resham Aaron
# 1       Darrell Abney
# 2       Rubén Algarra
# 3       Keith Acheson
# 4  Emanuel Bartolozzi
#
# [5 rows x 29 columns]

# %%
# Movies_2016_2017.columns
# del Movies_['genres']
# del Movies_['country_codes']
# del Movies_['language_codes']
# del Movies_['certificates']
# del Movies_['box_office']
# del Movies_['rating']
# del Movies_['votes']
# del Movies_['original_air_date']
# del Movies_['title']
# del Movies_['directors']
# del Movies_['producers']
# del Movies_['composers']
# del Movies_['editors']
# del Movies_['cinematographers']
# del Movies_['set_decorators']
# del Movies_['production_companies']
# del Movies_['assistant_directors']
# del Movies_['visual_effects']
#del Movies_['director1']
#del Movies_['director2']

# %%
# Movies_2016_2017.iloc[]

# %%
# moviesDB.get_movie(4034228)['box office']

# %%
# Movies_2016_2017['runtimes'] = runtime

# %%
# runtimes

# %%
for i in movies:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-3a409390f421> in <module>
# ----> 1 for i in movies:
#       2     print(i)
#
# NameError: name 'movies' is not defined
