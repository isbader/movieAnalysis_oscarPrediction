# %% [markdown]
# ## Project 3 (API Data Collection)

# %% [markdown]
# ## Name : Bader Abanmi
# ## Kaggle Link : https://www.kaggle.com/isbader/movie-dataset

# %% [markdown]
# ### Problem Statement
#
# **The movie industry is one of the largest entertainment industries in our time. It has been estimated that there are 500000 movies produced up to this point. These movies take a lot of time to make.
# I will try to use the IMDB API to try and make a dataset that will help me understand the movie features and what contributes to a movie
# being successful.**

# %% [markdown]
# |Feature|Type|Description|
# |---|---|---|
# |name|object|movie name|
# |budget|int64|movie budget|
# |release_date|object|release date of the movie|
# |vote_average|float64|vote_average 0 - 10|
# |adult|bool|This column gives if movie is for adults or no|
# |id|int64|Movie ID in the IMDB API |
# |language|object|Language code ex..(en = English)|
# |popularity|float64|Movie Popularity|
# |revenue|int64|Revenue of movie in one year|
# |runtime|float64|Movie run time in minutes|
# |status|object|Movie Status ex .(Released)|
# |tagline|object|Short tag line when marketing the movie |
# |title|object|movie title if there was an original title|
# |vote_count|int64|Count of people that voted|
# |First_genre|object|First genre of movie|
# |Second_genre|object|Second genre of movie|
# |Third_genre|object|Third genre of movie|
# |collection_name|object|Collection name if movie is part of a collection|

# %% [markdown]
# ### Imports

# %%
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# #### Understanding the API

# %%
data = requests.get("https://api.themoviedb.org/3/movie/9281?api_key=018dc56c083a046302ece29b691755ad").json() 
data #Check the API Data
# Out:
# {'adult': False,
#  'backdrop_path': '/QHlIf8JgLDOMpEOeuraSKTTjkJ.jpg',
#  'belongs_to_collection': None,
#  'budget': 12000000,
#  'genres': [{'id': 80, 'name': 'Crime'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 10749, 'name': 'Romance'},
#   {'id': 53, 'name': 'Thriller'}],
#  'homepage': None,
#  'id': 9281,
#  'imdb_id': 'tt0090329',
#  'original_language': 'en',
#  'original_title': 'Witness',
#  'overview': "A sheltered Amish child is the sole witness of a brutal murder in a restroom at a Philadelphia train station, and he must be protected.  The assignment falls to a taciturn detective who goes undercover in a Pennsylvania Dutch community. On the farm, he slowly assimilates despite his urban grit and forges a romantic bond with the child's beautiful mother.",
#  'popularity': 10.245,
#  'poster_path': '/pQZa314NJP3ieMAj6CgPI1v7nUY.jpg',
#  'production_companies': [{'id': 4,
#    'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png',
#    'name': 'Paramount',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1985-02-08',
#  'revenue': 68706993,
#  'runtime': 113,
#  'spoken_languages': [{'iso_639_1': 'de', 'name': 'Deutsch'},
#   {'iso_639_1': 'en', 'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'A big city cop. A small country boy. They have nothing in common... but a murder.',
#  'title': 'Witness',
#  'video': False,
#  'vote_average': 7.1,
#  'vote_count': 757}

# %% [markdown]
# **The MovieDB API only fetches one movie at a time**

# %%
data.keys() #The API Provides these features for each movie
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count'])

# %%
data = requests.get("https://api.themoviedb.org/3/movie/{}?api_key=018dc56c083a046302ece29b691755ad".format(989)).json()
print(data['id'],data['title']) #Testing the fetching mechanism
# Out:
# 989 The Mortal Storm

# %%
#This function will check if the movie ID is avalible or not (To avoid key_error)
def check_ava(counter):
    data = requests.get("https://api.themoviedb.org/3/movie/{}?api_key=018dc56c083a046302ece29b691755ad".format(counter)).json()
    try:
        a=data['id']
        return True
    except KeyError:
        return False

#Create lists to append the needed information

name = []
genres = []
budget = []
release_date = []
vote_average = []
adult = []
belongs_to_collection = []
movie_id = []
original_language = []
popularity = []
revenue = []
runtime = []
status = []
tagline = []
title = []
vote_count = []

# This function is a loop that takes manual movie ID's and retrieve the nassassary data
def import_movies(start,finish):
   
    for i in range(start,finish): #The function takes two parameters of where the surch starts and where the surch ends
        data = requests.get("https://api.themoviedb.org/3/movie/{}?api_key=018dc56c083a046302ece29b691755ad".format(i)).json() #Applied the API and looped over it using the API to itirate through the set range

        if check_ava(i) == True: #Applied check_ava to check if the movie ID is avalible or not
                #Appending the information to the lists created
                name.append(data['original_title'])
                genres.append(data['genres'])
                budget.append(data['budget'])
                release_date.append(data['release_date'])
                vote_average.append(data['vote_average'])
                adult.append(data['adult'])
                belongs_to_collection.append(data['belongs_to_collection'])
                movie_id.append(data['id'])
                original_language.append(data['original_language'])
                popularity.append(data['popularity'])
                #production_countries.append(data['production_countries'])
                revenue.append(data['revenue'])
                runtime.append(data['runtime'])
                status.append(data['status'])
                tagline.append(data['tagline'])
                title.append(data['title'])
                vote_count.append(data['vote_count'])
        else:
            pass

# %%
import_movies(1,17) #Use the import_movies function to import movies from the API

# %%
#Created a dataframe containing the lists that were created then changing it to a DataFrame and saving it 
movie_data = {'name':name,
              'genres':genres,
              'budget':budget,
              'release_date':release_date,
              'vote_average':vote_average,
              'adult':adult,
              'collection':belongs_to_collection,
              'id':movie_id,
              'language':original_language,
              'popularity':popularity,
              'revenue':revenue,
              'runtime':runtime,
              'status':status,
              'tagline':tagline,
              'title':title,
              'vote_count':vote_count}

movies = pd.DataFrame(movie_data)

movies.to_csv('movie_data_?_?.csv', index = False)

# %%
movies
# Out:
#                                 name  \
# 0                              Ariel
# 1               Varjoja paratiisissa
# 2                         Four Rooms
# 3                     Judgment Night
# 4   Life in Loops (A Megacities RMX)
# 5                  Sonntag im August
# 6                          Star Wars
# 7                       Finding Nemo
# 8                       Forrest Gump
# 9                    American Beauty
# 10                      Citizen Kane
# 11                Dancer in the Dark
#
#                                                genres    budget release_date  \
# 0   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...         0   1988-10-21
# 1   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...         0   1986-10-17
# 2   [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...   4000000   1995-12-09
# 3   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  21000000   1993-10-15
# 4                 [{'id': 99, 'name': 'Documentary'}]     42000   2006-01-01
# 5                       [{'id': 18, 'name': 'Drama'}]         0   2004-09-02
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  11000000   1977-05-25
# 7   [{'id': 16, 'name': 'Animation'}, {'id': 10751...  94000000   2003-05-30
# 8   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  55000000   1994-07-06
# 9                       [{'id': 18, 'name': 'Drama'}]  15000000   1999-09-15
# 10  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...    839727   1941-04-30
# 11  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...  12800000   2000-05-17
#
#     vote_average  adult                                         collection  \
# 0            6.9  False                                               None
# 1            7.4  False                                               None
# 2            6.1  False                                               None
# 3            6.6  False                                               None
# 4            7.4  False                                               None
# 5            6.7  False                                               None
# 6            8.2  False  {'id': 10, 'name': 'Star Wars Collection', 'po...
# 7            7.8  False  {'id': 137697, 'name': 'Finding Nemo Collectio...
# 8            8.4  False                                               None
# 9            8.0  False                                               None
# 10           8.1  False                                               None
# 11           7.9  False                                               None
#
#     id language  popularity    revenue  runtime    status  \
# 0    2       fi       8.848          0       73  Released
# 1    3       fi       9.169          0       72  Released
# 2    5       en      11.547    4300000       98  Released
# 3    6       en       8.485   12136938      110  Released
# 4    8       en       1.458          0       80  Released
# 5    9       de       0.808          0       15  Released
# 6   11       en      52.923  775398007      121  Released
# 7   12       en      21.367  940335536      100  Released
# 8   13       en      27.955  677945399      142  Released
# 9   14       en      21.979  356296601      122  Released
# 10  15       en      17.629   23217674      119  Released
# 11  16       en      14.127   40031879      141  Released
#
#                                               tagline  \
# 0
# 1
# 2   Twelve outrageous guests. Four scandalous requ...
# 3      Don't move. Don't whisper. Don't even breathe.
# 4                                 A Megacities remix.
# 5
# 6        A long time ago in a galaxy far, far away...
# 7   There are 3.7 trillion fish in the ocean. They...
# 8   Life is like a box of chocolates...you never k...
# 9                                        Look closer.
# 10                                     It's terrific!
# 11                        You don't need eyes to see.
#
#                                title  vote_count
# 0                              Ariel          86
# 1                Shadows in Paradise          97
# 2                         Four Rooms        1342
# 3                     Judgment Night         128
# 4   Life in Loops (A Megacities RMX)           9
# 5                   Sunday in August           6
# 6                          Star Wars       12268
# 7                       Finding Nemo       12496
# 8                       Forrest Gump       16137
# 9                    American Beauty        7072
# 10                      Citizen Kane        2666
# 11                Dancer in the Dark         870

# %% [markdown]
# ### Data Cleaning

# %%
data1 = pd.read_csv('Fetched_Data/movie_data_1000_5000.csv') #We saved the data in small sets to account for fetching delays

# %%
data2 = pd.read_csv('Fetched_Data/movie_data_5000_7000.csv')

# %%
data3 = pd.read_csv('Fetched_Data/movie_data_7000_10000.csv')

# %%
data4 = pd.read_csv('Fetched_Data/movie_data_10000_12000.csv')

# %%
data5 = pd.read_csv('Fetched_Data/movie_data_12000_15000.csv')

# %%
data6 = pd.read_csv('Fetched_Data/movie_data_15000_17000.csv')

# %%
data = pd.concat([data1,data2,data3,data4,data5,data6]) #Concat the data into one dataframe
data.shape
# Out:
# (9910, 16)

# %%
data.drop_duplicates(subset=None, keep='first', inplace=True) #Drop the duplicates

# %%
data.columns
# Out:
# Index(['name', 'genres', 'budget', 'release_date', 'vote_average', 'adult',
#        'collection', 'id', 'language', 'popularity', 'revenue', 'runtime',
#        'status', 'tagline', 'title', 'vote_count'],
#       dtype='object')

# %%
data.shape
# Out:
# (8603, 16)

# %%
data.head(5)
# Out:
#                  name                                             genres  \
# 0    Mulholland Drive  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 1         Adams æbler  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 2  Heavenly Creatures  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 3   Die Siebtelbauern                      [{'id': 18, 'name': 'Drama'}]
# 4       Il gattopardo                      [{'id': 18, 'name': 'Drama'}]
#
#      budget release_date  vote_average  adult collection    id language  \
# 0  15000000   2001-09-08           7.8  False        NaN  1018       en
# 1   3700000   2005-04-15           7.5  False        NaN  1023       da
# 2   5000000   1994-09-12           7.1  False        NaN  1024       en
# 3         0   1998-06-19           7.3  False        NaN  1039       de
# 4         0   1963-03-28           7.7  False        NaN  1040       it
#
#    popularity   revenue  runtime    status  \
# 0      16.046  20117339    147.0  Released
# 1       8.238         0     94.0  Released
# 2      11.453   3049135    109.0  Released
# 3       1.919         0     95.0  Released
# 4       9.634         0    186.0  Released
#
#                                              tagline               title  \
# 0  An actress longing to be a star. A woman searc...    Mulholland Drive
# 1                            When it rains, it pours       Adam's Apples
# 2                       Not all angels are innocent.  Heavenly Creatures
# 3  The rich get richer... and sometimes the poor ...      The Inheritors
# 4     Luchino Visconti's enduring romantic adventure         The Leopard
#
#    vote_count
# 0        3192
# 1         324
# 2         503
# 3           9
# 4         317

# %%
# We are getting the genres as a string therefore we will split the string to make it have three genres.
import ast # We import ast to evalute the string to change it from string to list

# We make three lists to contain the three genres
First_genre = []
Second_genre = []
Third_genre = []

for i in data['genres']: #We will loop over the list of genres and apend the vlaues to the lists we created
    #print(ast.literal_eval(i)) #check the work 
    if len(ast.literal_eval(i)) == 3: #First condition evalutes if the list len is 3 to append the needed values 
        First_genre.append(ast.literal_eval(i)[0]['name']) 
        Second_genre.append(ast.literal_eval(i)[1]['name'])
        Third_genre.append(ast.literal_eval(i)[2]['name'])
    elif len(ast.literal_eval(i)) == 2:#Second condition evalutes if the list len is 3 to append the needed values 
        First_genre.append(ast.literal_eval(i)[0]['name'])
        Second_genre.append(ast.literal_eval(i)[1]['name'])
        Third_genre.append(None)
    elif len(ast.literal_eval(i)) == 1:#First condition evalutes if the list len is 3 to append the needed values
        First_genre.append(ast.literal_eval(i)[0]['name'])
        Second_genre.append(None)
        Third_genre.append(None)
    else: #Else append all values with none
        First_genre.append(None)
        Second_genre.append(None)
        Third_genre.append(None)

# %%
data.head(5)
# Out:
#                  name                                             genres  \
# 0    Mulholland Drive  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 1         Adams æbler  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 2  Heavenly Creatures  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 3   Die Siebtelbauern                      [{'id': 18, 'name': 'Drama'}]
# 4       Il gattopardo                      [{'id': 18, 'name': 'Drama'}]
#
#      budget release_date  vote_average  adult collection    id language  \
# 0  15000000   2001-09-08           7.8  False        NaN  1018       en
# 1   3700000   2005-04-15           7.5  False        NaN  1023       da
# 2   5000000   1994-09-12           7.1  False        NaN  1024       en
# 3         0   1998-06-19           7.3  False        NaN  1039       de
# 4         0   1963-03-28           7.7  False        NaN  1040       it
#
#    popularity   revenue  runtime    status  \
# 0      16.046  20117339    147.0  Released
# 1       8.238         0     94.0  Released
# 2      11.453   3049135    109.0  Released
# 3       1.919         0     95.0  Released
# 4       9.634         0    186.0  Released
#
#                                              tagline               title  \
# 0  An actress longing to be a star. A woman searc...    Mulholland Drive
# 1                            When it rains, it pours       Adam's Apples
# 2                       Not all angels are innocent.  Heavenly Creatures
# 3  The rich get richer... and sometimes the poor ...      The Inheritors
# 4     Luchino Visconti's enduring romantic adventure         The Leopard
#
#    vote_count
# 0        3192
# 1         324
# 2         503
# 3           9
# 4         317

# %%
collection_name = []
for i in data['collection']: #This loop will loop over the collection and grab the name
    #print(type(i))
    if type(i) == str:
        collection_name.append(ast.literal_eval(i)['name'])
    else:
        collection_name.append(None)

# %%
# Here we are adding the collection name to our dataframe
data['collection_name'] = collection_name
# Here we are adding the genres to our DataFrame
data['First_genre'] = First_genre
data['Second_genre'] = Second_genre
data['Third_genre'] = Third_genre

# %%
data.head(40)
# Out:
#                                   name  \
# 0                     Mulholland Drive
# 1                          Adams æbler
# 2                   Heavenly Creatures
# 3                    Die Siebtelbauern
# 4                        Il gattopardo
# 5                            Sommersby
# 6                                   洗澡
# 7                The French Connection
# 8                              Blow-Up
# 9                           Breathless
# 10                             隠し砦の三悪人
# 11                      Arlington Road
# 12              Crna mačka, beli mačor
# 13                         Whale Rider
# 14                         Point Break
# 15                The Thirteenth Floor
# 16                           The Thing
# 17                       The Third Man
# 18           Ascenseur pour l'échafaud
# 19                Escape from New York
# 20  Die Geschichte vom weinenden Kamel
# 21                          Gespenster
# 22     The Wind That Shakes the Barley
# 23                        Catch a Fire
# 24                        The Prestige
# 25                          Dreamgirls
# 26                  In My Father's Den
# 27                           Princesas
# 28                  The Miracle Worker
# 29                  The Miracle Worker
# 30                               Babel
# 31                           The Queen
# 32             The Talented Mr. Ripley
# 33                     Das wilde Leben
# 34              The Remains of the Day
# 35                        Rocky Balboa
# 36                   The Good Shepherd
# 37                     Hannibal Rising
# 38                       Hollywoodland
# 39                         Ghost Rider
#
#                                                genres     budget release_date  \
# 0   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...   15000000   2001-09-08
# 1   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...    3700000   2005-04-15
# 2   [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...    5000000   1994-09-12
# 3                       [{'id': 18, 'name': 'Drama'}]          0   1998-06-19
# 4                       [{'id': 18, 'name': 'Drama'}]          0   1963-03-28
# 5   [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...          0   1993-02-05
# 6   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...          0   1999-09-13
# 7   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    1800000   1971-10-09
# 8   [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...    1800000   1966-12-18
# 9   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...          0   1983-05-13
# 10  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...          0   1958-12-28
# 11  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...   21500000   1999-03-19
# 12  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...          0   1998-06-01
# 13  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...    8000000   2003-01-30
# 14  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...   24000000   1991-07-12
# 15  [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...   16000000   1999-04-16
# 16  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...   15000000   1982-06-25
# 17  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...          0   1949-08-31
# 18  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...          0   1958-01-29
# 19  [{'id': 878, 'name': 'Science Fiction'}, {'id'...    6000000   1981-05-22
# 20  [{'id': 99, 'name': 'Documentary'}, {'id': 18,...          0   2003-06-29
# 21                      [{'id': 18, 'name': 'Drama'}]          0   2005-09-15
# 22  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...    6500000   2006-03-24
# 23  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...          0   2006-10-27
# 24  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...   40000000   2006-10-19
# 25                      [{'id': 18, 'name': 'Drama'}]   70000000   2006-12-25
# 26  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...          0   2004-06-11
# 27                      [{'id': 18, 'name': 'Drama'}]          0   2005-09-02
# 28                      [{'id': 18, 'name': 'Drama'}]     500000   1962-05-22
# 29  [{'id': 18, 'name': 'Drama'}, {'id': 10770, 'n...          0   2000-11-12
# 30                      [{'id': 18, 'name': 'Drama'}]   25000000   2006-09-08
# 31                      [{'id': 18, 'name': 'Drama'}]   15000000   2006-09-15
# 32  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...   40000000   1999-12-25
# 33  [{'id': 10402, 'name': 'Music'}, {'id': 18, 'n...          0   2007-02-01
# 34  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...   11500000   1993-11-05
# 35                      [{'id': 18, 'name': 'Drama'}]   24000000   2006-12-20
# 36  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...   85000000   2006-12-11
# 37  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...   50000000   2007-02-06
# 38  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...          0   2006-08-31
# 39  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...  110000000   2007-02-16
#
#     vote_average  adult                                         collection  \
# 0            7.8  False                                                NaN
# 1            7.5  False                                                NaN
# 2            7.1  False                                                NaN
# 3            7.3  False                                                NaN
# 4            7.7  False                                                NaN
# 5            6.3  False                                                NaN
# 6            7.2  False                                                NaN
# 7            7.6  False  {'id': 155474, 'name': 'French Connection Coll...
# 8            7.5  False                                                NaN
# 9            5.9  False                                                NaN
# 10           8.1  False                                                NaN
# 11           7.1  False                                                NaN
# 12           7.7  False                                                NaN
# 13           7.4  False                                                NaN
# 14           7.0  False                                                NaN
# 15           7.0  False                                                NaN
# 16           8.0  False  {'id': 479888, 'name': 'The Thing Collection',...
# 17           8.1  False                                                NaN
# 18           7.7  False                                                NaN
# 19           7.1  False  {'id': 115838, 'name': 'Escape From ... Collec...
# 20           7.8  False                                                NaN
# 21           7.1  False                                                NaN
# 22           7.4  False                                                NaN
# 23           6.5  False                                                NaN
# 24           8.2  False                                                NaN
# 25           6.7  False                                                NaN
# 26           7.7  False                                                NaN
# 27           7.1  False                                                NaN
# 28           7.7  False                                                NaN
# 29           6.6  False                                                NaN
# 30           7.1  False                                                NaN
# 31           7.0  False                                                NaN
# 32           7.2  False                                                NaN
# 33           6.8  False                                                NaN
# 34           7.5  False                                                NaN
# 35           6.7  False  {'id': 1575, 'name': 'Rocky Collection', 'post...
# 36           6.4  False                                                NaN
# 37           6.1  False  {'id': 9743, 'name': 'The Hannibal Lecter Coll...
# 38           6.2  False                                                NaN
# 39           5.4  False  {'id': 90306, 'name': 'Ghost Rider Collection'...
#
#       id language  popularity    revenue  runtime    status  \
# 0   1018       en      16.046   20117339    147.0  Released
# 1   1023       da       8.238          0     94.0  Released
# 2   1024       en      11.453    3049135    109.0  Released
# 3   1039       de       1.919          0     95.0  Released
# 4   1040       it       9.634          0    186.0  Released
# 5   1049       en       9.177  140081992    109.0  Released
# 6   1050       zh       2.519          0     92.0  Released
# 7   1051       en      16.423   41158757    104.0  Released
# 8   1052       en      12.830          0    111.0  Released
# 9   1058       en       9.396   19910002    100.0  Released
# 10  1059       ja      10.070          0    139.0  Released
# 11  1073       en      12.766          0    117.0  Released
# 12  1075       sr       7.669          0    127.0  Released
# 13  1088       en       9.779   41400000    101.0  Released
# 14  1089       en      13.969   83531958    120.0  Released
# 15  1090       en      14.542   18564088    101.0  Released
# 16  1091       en      21.279   19629760    109.0  Released
# 17  1092       en      13.522     596349    105.0  Released
# 18  1093       fr       6.192     263404     91.0  Released
# 19  1103       en      14.473   50244700     99.0  Released
# 20  1114       mn       3.784          0     91.0  Released
# 21  1115       de       1.933          0     85.0  Released
# 22  1116       en      10.461   22889018    124.0  Released
# 23  1123       en       6.335    4291965    101.0  Released
# 24  1124       en      17.216  109676311    130.0  Released
# 25  1125       en      10.353  154937680    134.0  Released
# 26  1126       en       5.205          0    126.0  Released
# 27  1127       es       3.226          0    113.0  Released
# 28  1162       en       7.086    2500000    106.0  Released
# 29  1163       en       4.662          0     95.0  Released
# 30  1164       en      12.691  135330182    143.0  Released
# 31  1165       en      10.727  123384128    103.0  Released
# 32  1213       en      12.413  128798265    139.0  Released
# 33  1244       de       4.275     957744    114.0  Released
# 34  1245       en      10.533   23237911    134.0  Released
# 35  1246       en      15.322  155721132    102.0  Released
# 36  1247       en      11.631   59908565    167.0  Released
# 37  1248       en       2.615   82169884    121.0  Released
# 38  1249       en       9.675   16803753    126.0  Released
# 39  1250       en      16.903  228738393    114.0  Released
#
#                                               tagline  \
# 0   An actress longing to be a star. A woman searc...
# 1                             When it rains, it pours
# 2                        Not all angels are innocent.
# 3   The rich get richer... and sometimes the poor ...
# 4      Luchino Visconti's enduring romantic adventure
# 5   She knew his face. His touch. His voice. She k...
# 6                                                 NaN
# 7   There are no rules and no holds barred when Po...
# 8         Michelangelo Antonioni's first British film
# 9   He's the last man on earth any woman needs - b...
# 10                                                NaN
# 11                             Your Paranoia Is Real.
# 12                                                NaN
# 13  In the ways of the ancients she found a hope f...
# 14                              100% Pure Adrenaline!
# 15                                  Question reality.
# 16                  Man is The Warmest Place to Hide.
# 17                 Hunted by men ... Sought by WOMEN!
# 18  Frantic for life and love - Frantic for excite...
# 19              New York is a disease. Meet the cure.
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23              The spark that ignites us, unites us.
# 24                          Are You Watching Closely?
# 25                   One Dream Will Change Everything
# 26                                                NaN
# 27                                                NaN
# 28                           An emotional earthquake!
# 29                                                NaN
# 30              If You Want to be Understood...Listen
# 31                            Our Leaders. Ourselves.
# 32       How far would you go to become someone else?
# 33                                                NaN
# 34                               Diamond in the Rough
# 35                      It ain't over 'til it's over.
# 36  The untold story of the most powerful covert a...
# 37                           It started with revenge.
# 38  Living in Hollywood can make you famous. Dying...
# 39                      Hell is About To Be Unleashed
#
#                               title  vote_count  \
# 0                  Mulholland Drive        3192
# 1                     Adam's Apples         324
# 2                Heavenly Creatures         503
# 3                    The Inheritors           9
# 4                       The Leopard         317
# 5                         Sommersby         175
# 6                            Shower          29
# 7             The French Connection         819
# 8                           Blow-Up         555
# 9                        Breathless         108
# 10              The Hidden Fortress         231
# 11                   Arlington Road         498
# 12             Black Cat, White Cat         320
# 13                      Whale Rider         184
# 14                      Point Break        1751
# 15             The Thirteenth Floor         675
# 16                        The Thing        3385
# 17                    The Third Man         855
# 18          Elevator to the Gallows         205
# 19             Escape from New York        1484
# 20   The Story of the Weeping Camel          54
# 21                           Ghosts          13
# 22  The Wind That Shakes the Barley         336
# 23                     Catch a Fire          53
# 24                     The Prestige        8849
# 25                       Dreamgirls         546
# 26               In My Father's Den          47
# 27                       Princesses          37
# 28               The Miracle Worker         127
# 29               The Miracle Worker          17
# 30                            Babel        2050
# 31                        The Queen         677
# 32          The Talented Mr. Ripley        1480
# 33                 Eight Miles High          18
# 34           The Remains of the Day         527
# 35                     Rocky Balboa        1857
# 36                The Good Shepherd         578
# 37                  Hannibal Rising        1168
# 38                    Hollywoodland         184
# 39                      Ghost Rider        3486
#
#                    collection_name      First_genre     Second_genre  \
# 0                             None         Thriller            Drama
# 1                             None            Drama           Comedy
# 2                             None            Drama          Fantasy
# 3                             None            Drama             None
# 4                             None            Drama             None
# 5                             None             None             None
# 6                             None           Comedy            Drama
# 7     French Connection Collection           Action            Crime
# 8                             None            Drama          Mystery
# 9                             None             None             None
# 10                            None             None             None
# 11                            None             None             None
# 12                            None           Comedy          Romance
# 13                            None            Drama           Family
# 14                            None           Action         Thriller
# 15                            None         Thriller  Science Fiction
# 16            The Thing Collection           Horror          Mystery
# 17                            None         Thriller          Mystery
# 18                            None            Drama         Thriller
# 19      Escape From ... Collection  Science Fiction           Action
# 20                            None      Documentary            Drama
# 21                            None            Drama             None
# 22                            None            Drama              War
# 23                            None           Action            Drama
# 24                            None            Drama          Mystery
# 25                            None            Drama             None
# 26                            None            Drama         Thriller
# 27                            None            Drama             None
# 28                            None            Drama             None
# 29                            None            Drama         TV Movie
# 30                            None            Drama             None
# 31                            None            Drama             None
# 32                            None         Thriller            Crime
# 33                            None            Music            Drama
# 34                            None            Drama          Romance
# 35                Rocky Collection            Drama             None
# 36                            None            Drama         Thriller
# 37  The Hannibal Lecter Collection             None             None
# 38                            None            Drama         Thriller
# 39          Ghost Rider Collection             None             None
#
#         Third_genre
# 0           Mystery
# 1             Crime
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7          Thriller
# 8          Thriller
# 9              None
# 10             None
# 11             None
# 12             None
# 13             None
# 14            Crime
# 15          Mystery
# 16  Science Fiction
# 17             None
# 18            Crime
# 19             None
# 20             None
# 21             None
# 22             None
# 23         Thriller
# 24         Thriller
# 25             None
# 26             None
# 27             None
# 28             None
# 29             None
# 30             None
# 31             None
# 32            Drama
# 33           Comedy
# 34             None
# 35             None
# 36          History
# 37             None
# 38            Crime
# 39             None

# %%
#Deleting unnassary columns
del data['genres']
del data['collection']

# %%
data.head()
data.dtypes
# Out:
# name                object
# budget               int64
# release_date        object
# vote_average       float64
# adult                 bool
# id                   int64
# language            object
# popularity         float64
# revenue              int64
# runtime            float64
# status              object
# tagline             object
# title               object
# vote_count           int64
# collection_name     object
# First_genre         object
# Second_genre        object
# Third_genre         object
# dtype: object

# %%
data.to_csv('Project3_data.csv', index = False)

# %%
data.shape
# Out:
# (8603, 18)
