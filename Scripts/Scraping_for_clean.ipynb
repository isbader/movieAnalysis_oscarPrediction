# %%
#pip install selenium

# %%
import requests
import random
import re
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
n=[]
link = 'https://pro.imdb.com/title/tt0170016/details'
print(link)
response = requests.get(link)
print(response.status_code)
soup = BeautifulSoup(response.text, 'html.parser')
movieName = soup.find('h1')
movieName.text
# Out:
# https://pro.imdb.com/title/tt0170016/details
# 200
# 'How the Grinch Stole Christmas (2000)'

# %%
soup
# Out:
# <!DOCTYPE doctype html>
# <!--[if IE 8]><html class="a-no-js a-lt-ie10 a-lt-ie9 a-ie8" data-19ax5a9jf="dingo"><![endif]--><!--[if IE 9]><html class="a-no-js a-lt-ie10 a-ie9" data-19ax5a9jf="dingo"><![endif]--><!--[if !IE]><!--><html class="a-no-js" data-19ax5a9jf="dingo"><!--<![endif]--><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><script data-a-state='{"key": "csm"}' type="a-state">
# {"pageType": "title", "subpageType": "v2_cast_public"}
# </script>
# <meta content="See How the Grinch Stole Christmas's production, company, and contact information. Explore How the Grinch Stole Christmas's box office performance, follow development, and track popularity with MOVIEmeter. IMDbPro — The essential resource for entertainment professionals." name="description"/>
# <meta content="https://m.media-amazon.com/images/M/MV5BNWNiNTczNzEtMjQyZC00MjFmLTkzMDMtODk4ZGMyZmE0N2E4XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg" property="og:image">
# ...

# %%
#rate = soup.select(id_="running_time")
rate = soup.select('span[id^="running_time"]')
rate[0].text
# Out:
# ' 104 min\n'

# %%
genres = soup.select('span[id^="genres"]')
genres[0].text
# Out:
# 'Comedy, Family, Fantasy'

# %%
plot = soup.select('div[id^="title_summary"]')

# %%
plot[0].text.split('\n')[1]
# Out:
# 'On the outskirts of Whoville lives a green, revenge-seeking Grinch (Jim Carrey), who plans to ruin Christmas for all of the citizens of the town.'

# %%
#director = soup.select('a',class_="a-size- a-align- a-link- ttip")

# %%
#director

# %%
soup.select('div[id^="box_office_summary"]')[0].text
# Out:
# ' Box Office\n\n\nBecome a member to see Box Office information about How the Grinch Stole Christmas.\n Start your 30-Day free trial\n\n'

# %%
soup.find_all('div',class_='a-section a-spacing-mini header_section')
# Out:
# [<div class="a-section a-spacing-mini header_section" id="box_office_summary"><div class="a-row header highlight_header background_color_storm"><div class="a-column a-span12 a-span-last"><span class="a-size-base a-text-bold"> Box Office
#  </span></div></div>
#  <div class="a-section a-spacing-top-mini">
#  <p class="a-text-left a-size-base-plus a-color-secondary">Become a member to see Box Office information about How the Grinch Stole Christmas.</p>
#  <a class="a-link-normal" data-bypasspublicrestriction="true" href="/login/ap?u=/login/lwa&amp;imdbPageAction=signUp"><p class="a-text-left"><span class="a-button a-button-primary"><span class="a-button-inner"><input class="a-button-input" type="submit"/><span aria-hidden="true" class="a-button-text"> Start your 30-Day free trial
#  </span></span></span></p></a>
#  </div></div>]

# %%
soup.find_all('div',class_='a-section a-spacing-mini header_section')
# Out:
# [<div class="a-section a-spacing-mini header_section" id="box_office_summary"><div class="a-row header highlight_header background_color_storm"><div class="a-column a-span12 a-span-last"><span class="a-size-base a-text-bold"> Box Office
#  </span></div></div>
#  <div class="a-section a-spacing-top-mini">
#  <p class="a-text-left a-size-base-plus a-color-secondary">Become a member to see Box Office information about How the Grinch Stole Christmas.</p>
#  <a class="a-link-normal" data-bypasspublicrestriction="true" href="/login/ap?u=/login/lwa&amp;imdbPageAction=signUp"><p class="a-text-left"><span class="a-button a-button-primary"><span class="a-button-inner"><input class="a-button-input" type="submit"/><span aria-hidden="true" class="a-button-text"> Start your 30-Day free trial
#  </span></span></span></p></a>
#  </div></div>]

# %%
soup.find_all('div',class_="a-section a-spacing-top-mini")
# Out:
# [<div class="a-section a-spacing-top-mini">
#  <p class="a-text-left a-size-base-plus a-color-secondary">Become a member to see MOVIEmeter and news information about How the Grinch Stole Christmas.</p>
#  <a class="a-link-normal" data-bypasspublicrestriction="true" href="/login/ap?u=/login/lwa&amp;imdbPageAction=signUp"><p class="a-text-left"><span class="a-button a-button-primary"><span class="a-button-inner"><input class="a-button-input" type="submit"/><span aria-hidden="true" class="a-button-text"> Start your 30-Day free trial
#  </span></span></span></p></a>
#  </div>, <div class="a-section a-spacing-top-mini">
#  <p class="a-text-left a-size-base-plus a-color-secondary">Become a member to see Box Office information about How the Grinch Stole Christmas.</p>
# ...

# %%
soup.find_all('div',class_="a-column a-span5 a-text-right a-span-last")
# Out:
# []

# %%
# budget = soup.findall('div',class_="a-fixed-right-grid-col a-col-right")

# %%
pwd
# Out:
# '/Users/bader/Dropbox/DSI_GA_Capstone/Code/Bader/Scripts'

# %%
movies = pd.read_csv('/Users/bader/Dropbox/DSI_GA_Capstone/Code/New_Data_OMDB/movies_2000_new.csv')

# %%
movies['imdbID']
# Out:
# 0      tt0160127
# 1      tt0172495
# 2      tt0170016
# 3      tt0180093
# 4      tt0210945
#          ...
# 642    tt4135936
# 643    tt4138432
# 644    tt7201596
# 645          NaN
# 646    tt3180664
# Name: imdbID, Length: 647, dtype: object

# %%
ID = movies['imdbID'][0:10]
name = []
runtime = []
genres = []
plot = []

for i in ID:
    try:
        if type(i) == str:
            link = 'https://pro.imdb.com/title/{}/details'.format(i)
            print(link)
            response = requests.get(link)
            print(response.status_code)
            soup = BeautifulSoup(response.text, 'html.parser')
            try:
                name.append(soup.find('h1').text)
            except:
                name.append(None)
            try:
                runtime.append(soup.select('span[id^="running_time"]')[0].text)
            except:
                runtime.append(None)
            try:
                genres.append(soup.select('span[id^="genres"]'))
            except:
                genres.append(None)
            try:
                plot.append(soup.select('div[id^="title_summary"]')[0].text.split('\n')[1])
            except:
                plot.append(None)
                
    except:
        name.append(None)
        runtime.append(None)
# Out:
# https://pro.imdb.com/title/tt0160127/details
# 200
# https://pro.imdb.com/title/tt0172495/details
# 200
# https://pro.imdb.com/title/tt0170016/details
# 200
# https://pro.imdb.com/title/tt0180093/details
# 200
# https://pro.imdb.com/title/tt0210945/details
# 200
# https://pro.imdb.com/title/tt0144084/details
# 200
# https://pro.imdb.com/title/tt0208092/details
# 200
# https://pro.imdb.com/title/tt0191397/details
# 200
# https://pro.imdb.com/title/tt0209144/details
# 200
# https://pro.imdb.com/title/tt0187393/details
# 200

# %%
print(len(ID))
print(len(name))
print(len(runtime))
print(len(genres))
print(len(plot))
# Out:
# 10
# 10
# 10
# 10
# 10

# %%
ID_ = ID.dropna()

# %%
print(len(ID_))
print(len(name))
print(len(runtime))
print(len(genres))
print(len(plot))
# Out:
# 10
# 10
# 10
# 10
# 10

# %%
df_ = pd.DataFrame({'ID':ID_,'name':name,'runtime':runtime,'genres':genres,'plot':plot})

# %%
df_.head()
# Out:
#           ID                                   name     runtime  \
# 0  tt0160127                Charlie's Angels (2000)    98 min\n
# 1  tt0172495                       Gladiator (2000)   155 min\n
# 2  tt0170016  How the Grinch Stole Christmas (2000)   104 min\n
# 3  tt0180093             Requiem for a Dream (2000)   102 min\n
# 4  tt0210945             Remember the Titans (2000)   113 min\n
#
#                           genres  \
# 0  [[Action, Adventure, Comedy]]
# 1   [[Action, Adventure, Drama]]
# 2    [[Comedy, Family, Fantasy]]
# 3                      [[Drama]]
# 4    [[Biography, Drama, Sport]]
#
#                                                 plot
# 0  Three women, detectives with a mysterious boss...
# 1  A former Roman General sets out to exact venge...
# 2  On the outskirts of Whoville lives a green, re...
# 3  The drug-induced utopias of four Coney Island ...
# 4  The true story of a newly appointed African-Am...

# %%
ls
# Out:
# Chrome/                          TMDB_API_data_collection.ipynb
# Cleaning_and_Feature_Eng.ipynb   datasource_API/
# Fixing_cast.ipynb                getting_movies_names.ipynb
# Mapping_cert.ipynb               getting_movies_names.ipynb copy
# Scraping_for_clean.ipynb         multi-thread_script.ipynb
# Script_3.ipynb                   person_info.ipynb

# %% [markdown]
# # Selenium

# %%
driver = webdriver.Chrome(executable_path='Chrome/chromedriver')
driver.get('https://www.imdb.com/title/tt0172495/?openid.assoc_handle=imdb_us&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.mode=logout&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&openid.return_to=https%3A%2F%2Fwww.imdb.com%2Ftitle%2Ftt0172495%2F&')
a = driver.find_elements_by_class_name('inline')
#sleep(2000) # Delay execution for a given number of seconds.

html = driver.page_source # property/attribute -- Gets the source of the current page.
driver.close()

# %%
a
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="94b2e15832e4986872d5f636c52082c4", element="25b9bfce-b325-4158-810d-d225d5b20efd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b2e15832e4986872d5f636c52082c4", element="147bc678-e5c8-4a49-ae0c-7cf4f2fa96ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b2e15832e4986872d5f636c52082c4", element="30abb633-5806-4c71-b026-97e974612d22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b2e15832e4986872d5f636c52082c4", element="3ebe2c53-2ce6-4e85-9aa3-cf37034c162c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b2e15832e4986872d5f636c52082c4", element="73dae3d2-6652-4335-8350-077357df0b3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="94b2e15832e4986872d5f636c52082c4", element="e2f08988-e861-4fcd-816f-64793f2e3f4c")>,
# ...

# %%
pwd
# Out:
# '/Users/bader/Dropbox/DSI_GA_Capstone/Code/Bader/Scripts'

# %% [markdown]
# ## IMDB_web_scrape

# %%
n=[]
link = 'https://www.imdb.com/title/tt0172495/?openid.assoc_handle=imdb_us&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.mode=logout&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&openid.return_to=https%3A%2F%2Fwww.imdb.com%2Ftitle%2Ftt0172495%2F&'
print(link)
response = requests.get(link)
print(response.status_code)
soup = BeautifulSoup(response.text, 'html.parser')
movieName = soup.find('h1')
movieName.text
# Out:
# https://www.imdb.com/title/tt0172495/?openid.assoc_handle=imdb_us&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.mode=logout&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&openid.return_to=https%3A%2F%2Fwww.imdb.com%2Ftitle%2Ftt0172495%2F&
# 200
# 'Gladiator\xa0(2000) '

# %%
soup.find_all('div',class_='subtext')
# Out:
# [<div class="subtext">
#                      R
#      <span class="ghost">|</span> <time datetime="PT155M">
#                          2h 35min
#                      </time>
#  <span class="ghost">|</span>
#  <a href="/search/title?genres=action&amp;explore=title_type,genres">Action</a>,
#  <a href="/search/title?genres=adventure&amp;explore=title_type,genres">Adventure</a>,
#  <a href="/search/title?genres=drama&amp;explore=title_type,genres">Drama</a>
#  <span class="ghost">|</span>
#  <a href="/title/tt0172495/releaseinfo" title="See more release dates">5 May 2000 (USA)
#  </a> </div>]

# %%
soup.find('h4',class_="inline")
# Out:
# <h4 class="inline">Director:</h4>

# %%
soup.find_all('div',class_="a-column a-span5 a-text-right a-span-last")
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///title/tt0172495?src=mdot" name="apple-itunes-app"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Gladiator (2000) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
# ...
