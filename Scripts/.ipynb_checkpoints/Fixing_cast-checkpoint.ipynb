# %%
import numpy as np
import pandas as pd
import imdb

# %%
Movie_names = pd.read_csv('Movies_2016_2017.csv') #Get the movies

# %%
Movie_names.head()
# Out:
#    year               name  Movie_ID  runtime  \
# 0  2016          Rogue One   3748528    133.0
# 1  2016      Suicide Squad   1386697    123.0
# 2  2016      Hacksaw Ridge   2119532    139.0
# 3  2016              Moana   3521164    107.0
# 4  2016  London Has Fallen   3300542     99.0
#
#                                                 cast  \
# 0  [<Person id:0428065[http] name:_Felicity Jones...
# 1  [<Person id:0000226[http] name:_Will Smith_>, ...
# 2  [<Person id:1940449[http] name:_Andrew Garfiel...
# 3  [<Person id:7635388[http] name:_Auli'i Cravalh...
# 4  [<Person id:0009530[http] name:_Alon Aboutboul...
#
#                                                genre       country_codes  \
# 0                  ['Action', 'Adventure', 'Sci-Fi']              ['us']
# 1       ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']              ['us']
# 2           ['Biography', 'Drama', 'History', 'War']        ['au', 'us']
# ...

# %%
Movie_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1901 entries, 0 to 1900
# Data columns (total 29 columns):
# year                   1901 non-null int64
# name                   1901 non-null object
# Movie_ID               1901 non-null int64
# runtime                1750 non-null float64
# cast                   1859 non-null object
# genre                  1860 non-null object
# country_codes          1885 non-null object
# language_codes         1859 non-null object
# certificates           1268 non-null object
# Budget                 857 non-null float64
# OWUS                   520 non-null object
# CWG                    401 non-null float64
# rating                 1693 non-null float64
# votes                  1693 non-null float64
# original_air_date      1676 non-null object
# title                  1901 non-null object
# director               1838 non-null object
# writer1                1773 non-null object
# writer2                449 non-null object
# ...

# %%
Movie_names['cast'][0]
# Out:
# "[<Person id:0428065[http] name:_Felicity Jones_>, <Person id:0526019[http] name:_Diego Luna_>, <Person id:0876138[http] name:_Alan Tudyk_>, <Person id:0947447[http] name:_Donnie Yen_>, <Person id:0422638[http] name:_Wen Jiang_>, <Person id:0578853[http] name:_Ben Mendelsohn_>, <Person id:0377844[http] name:_Guy Henry_>, <Person id:0001845[http] name:_Forest Whitaker_>, <Person id:1981893[http] name:_Riz Ahmed_>, <Person id:0586568[http] name:_Mads Mikkelsen_>, <Person id:0001751[http] name:_Jimmy Smits_>, <Person id:0677944[http] name:_Alistair Petrie_>, <Person id:0642444[http] name:_Genevieve O'Reilly_>, <Person id:0199842[http] name:_Ben Daniels_>, <Person id:1208004[http] name:_Paul Kasey_>, <Person id:0822812[http] name:_Stephen Stanton_>, <Person id:0568400[http] name:_Ian McElhinney_>, <Person id:0267241[http] name:_Fares Fares_>, <Person id:0034877[http] name:_Jonathan Aris_>, <Person id:1004267[http] name:_Sharon Duncan-Brewster_>, <Person id:1872855[http] name:_Spencer Wil
# ...

# %%
Movie_names['cast'][503]
# Out:
# "[<Person id:0788335[http] name:_Michael Shannon_>, <Person id:0000228[http] name:_Kevin Spacey_>, <Person id:1641117[http] name:_Alex Pettyfer_>, <Person id:0424216[http] name:_Johnny Knoxville_>, <Person id:0004988[http] name:_Colin Hanks_>, <Person id:1404239[http] name:_Evan Peters_>, <Person id:3650037[http] name:_Sky Ferreira_>, <Person id:0504832[http] name:_Tracy Letts_>, <Person id:0004883[http] name:_Tate Donovan_>, <Person id:1667364[http] name:_Ashley Benson_>, <Person id:3878170[http] name:_Kamal Angelo Bolden_>, <Person id:1501738[http] name:_Ahna O'Reilly_>, <Person id:3859945[http] name:_Ian Hoch_>, <Person id:0599907[http] name:_Ritchie Montgomery_>, <Person id:2093939[http] name:_Nathalie Love_>, <Person id:4990595[http] name:_Atlanta De Cadenet Taylor_>, <Person id:8081393[http] name:_Skye Peters_>, <Person id:0755966[http] name:_Joey Sagal_>, <Person id:3518672[http] name:_Poppy Delevingne_>, <Person id:0114177[http] name:_Marcus Lyle Brown_>, <Person id:0545008[h
# ...

# %%
w = Movie_names['cast']
for c in range (len(w)):
    print(c,type(w[c]))
# Out:
# 0 <class 'str'>
# 1 <class 'str'>
# 2 <class 'str'>
# 3 <class 'str'>
# 4 <class 'str'>
# 5 <class 'str'>
# 6 <class 'str'>
# 7 <class 'str'>
# 8 <class 'str'>
# 9 <class 'str'>
# 10 <class 'str'>
# 11 <class 'str'>
# 12 <class 'str'>
# 13 <class 'str'>
# 14 <class 'str'>
# 15 <class 'str'>
# 16 <class 'str'>
# 17 <class 'str'>
# 18 <class 'str'>
# 19 <class 'str'>
# 20 <class 'str'>
# 21 <class 'str'>
# 22 <class 'str'>
# 23 <class 'str'>
# 24 <class 'str'>
# 25 <class 'str'>
# 26 <class 'str'>
# 27 <class 'str'>
# 28 <class 'str'>
# 29 <class 'str'>
# 30 <class 'str'>
# 31 <class 'str'>
# 32 <class 'str'>
# 33 <class 'str'>
# 34 <class 'str'>
# 35 <class 'str'>
# 36 <class 'str'>
# 37 <class 'str'>
# 38 <class 'str'>
# 39 <class 'str'>
# 40 <class 'str'>
# 41 <class 'str'>
# 42 <class 'str'>
# 43 <class 'str'>
# 44 <class 'str'>
# 45 <class 'str'>
# 46 <class 'str'>
# 47 <class 'str'>
# 48 <class 'str'>
# 49 <class 'str'>
# 50 <class 'str'>
# 51 <class 'str'>
# 52 <class 'str'>
# ...

# %%
castnames=[]
for x in w:
    thisn = []
    try:
        l = x.split(',')
        for n in l:
            rindx = n.find('name:_')
            endindx = n.find('_>',rindx)
            mem = n[rindx+6:endindx]
            thisn.append(mem)
        castnames.append(thisn)
    except:
        castnames.append(None)

# %%
len(castnames)
# Out:
# 1901

# %%
Movie_names['cast'] = castnames

# %%
Movie_names.head()
# Out:
#    year               name  Movie_ID  runtime  \
# 0  2016          Rogue One   3748528    133.0
# 1  2016      Suicide Squad   1386697    123.0
# 2  2016      Hacksaw Ridge   2119532    139.0
# 3  2016              Moana   3521164    107.0
# 4  2016  London Has Fallen   3300542     99.0
#
#                                                 cast  \
# 0  [Felicity Jones, Diego Luna, Alan Tudyk, Donni...
# 1  [Will Smith, Jaime FitzSimons, Ike Barinholtz,...
# 2  [Andrew Garfield, Richard Pyros, Jacob Warner,...
# 3  [Auli'i Cravalho, Dwayne Johnson, Rachel House...
# 4  [Alon Aboutboul, Waleed Zuaiter, Adel Bencheri...
#
#                                                genre       country_codes  \
# 0                  ['Action', 'Adventure', 'Sci-Fi']              ['us']
# 1       ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']              ['us']
# 2           ['Biography', 'Drama', 'History', 'War']        ['au', 'us']
# ...

# %%
export_csv = Movie_names.to_csv (r'Movies_2016_2017_castfixed.csv', index = None, header=True)
